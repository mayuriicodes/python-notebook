# %% [markdown]
# **DATATYPES**

# %% [markdown]
# - INT
# - float
# - string
# - list
# - tuple
# - set
# - dictionary
# - bool
# - complex
# - range
# - byte
# - byte array
# - memory view
# - none type

# %% [markdown]
# $integer$

# %%
num=10
num
# Out:
# 10

# %%
type(num)
# Out:
# int

# %% [markdown]
# $float$

# %% [markdown]
# **e representation**

# %%
1e+1
# Out:
# 10.0

# %%
1e1
# Out:
# 10.0

# %%
1e2
# Out:
# 100.0

# %%
1e3
# Out:
# 1000.0

# %%
2e4 #2* 10000
# Out:
# 20000.0

# %%
1e-4 #1/10000
# Out:
# 0.0001

# %% [markdown]
# $boolean$

# %%
val=True
val
# Out:
# True

# %%
type(val)
# Out:
# bool

# %%
val1=False
type(val1)
# Out:
# bool

# %% [markdown]
# $strings$

# %% [markdown]
# - english format representation
# - strings represent with quotes
# - we can use single , double and tripple quotes

# %%
name='python'
name
# Out:
# 'python'

# %%
type(name)
# Out:
# str

# %%
print(name) #when you print it will not able to see the quotes
# Out:
# python

# %%
val="10"
type(val)
# Out:
# str

# %%
str1=' i love "python"'
print(str1)
# Out:
#  i love "python"

# %% [markdown]
# **triple quotes**
#
# - triple quotes is not use in coding part
# - this process is called as **doc string**

# %%
"""hi there
im python 
easy pizy"""
