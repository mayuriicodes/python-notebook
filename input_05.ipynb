# %%
input()
# Out:
#  nareshit
# 'nareshit'

# %%
name=input()
# Out:
#  prepro

# %%
name
# Out:
# 'prepro'

# %%
a=input()
b=input()
c=input()
# Out:
#  10
#  20
#  30

# %%
type(a)
# Out:
# str

# %%
input("enter number: ")
# Out:
# enter number:  2
# '2'

# %%
a=input("enter number 1: ")#input value by default string type
b=input("enter number 2: ")
a+b
# Out:
# enter number 1:  1
# enter number 2:  2
# '12'

# %%
a=int(input("enter number 1: "))
b=int(input("enter number 2: "))
a+b
# Out:
# enter number 1:  1
# enter number 2:  2
# 3

# %% [markdown]
# **eval**

# %% [markdown]
# - evaluate

# %%
int('10')   #10
int('10.5') #error

float('10') #10.0
float('10.5')#10.5

# %%
eval('10'), eval('10.5')
# Out:
# (10, 10.5)

# %%
n1=eval(input('enter'))
n2=eval(input('enter'))
n1+n2
# Out:
# enter 10.5
# enter 20
# 30.5

# %%
#wap to calculate area of circle----take input from user
radius=eval(input('enter radius of circle'))
pi=3.14
area=pi*radius*radius
area
# Out:
# enter radius of circle 3
# 28.259999999999998
