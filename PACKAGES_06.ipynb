# %%
#SYNTAX
import <package name>

# %%
import random

# %%
import math

# %%
import numpy

# %%
import time

# %%
import keyword

# %%
import pandas

# %%
pandas
# Out:
# <module 'pandas' from 'C:\\Users\\Admin\\AppData\\Roaming\\Python\\Python313\\site-packages\\pandas\\__init__.py'>

# %%
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x000001B1A3151530>>

# %%
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
random.randint(10,20)
# Out:
# 14

# %%
import random
dir(random)
help(random.randint)
random.randint(1,10)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.
# 5

# %%
import math
math.sqrt(9)
# Out:
# 3.0

# %%
import math
math.pow(2,3)
# Out:
# 8.0

# %%
import math
math.pi
# Out:
# 3.141592653589793

# %%
import math
math.sin(8)
# Out:
# 0.9893582466233818

# %%
dir(time)
# Out:
# ['_STRUCT_TM_ITEMS',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'altzone',
#  'asctime',
#  'ctime',
#  'daylight',
#  'get_clock_info',
#  'gmtime',
#  'localtime',
#  'mktime',
#  'monotonic',
#  'monotonic_ns',
#  'perf_counter',
#  'perf_counter_ns',
#  'process_time',
#  'process_time_ns',
#  'sleep',
#  'strftime',
#  'strptime',
#  'struct_time',
#  'thread_time',
#  'thread_time_ns',
#  'time',
#  'time_ns',
#  'timezone',
#  'tzname']

# %%
print('hello')
time.sleep(5)
print('bye')
# Out:
# hello
# bye

# %%
import keyword
dir(keyword)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'iskeyword',
#  'issoftkeyword',
#  'kwlist',
#  'softkwlist']

# %%
start=time.time()
time.sleep(5)
end=time.time()
print(end-start)
# Out:
# 5.001279354095459

# %%
import random
random.sample(['red','red','red','red','blue','blue'],k=3)
# Out:
# ['blue', 'blue', 'red']

# %%
from random import sample
sample(['red','red','red','red','blue','blue'],k=3)
# Out:
# ['red', 'blue', 'red']

# %%
from random import sample as smp
smp(['red','red','red','red','blue','blue'],k=3)
# Out:
# ['red', 'blue', 'red']

# %%
from math import sqrt
sqrt(9)
# Out:
# 3.0

# %%
n1=eval(input('enter'))
n2=eval(input('enter'))
n1+n2
# Out:
# enter 2
# enter 3
# 5

# %%
n1=random.randint(1,100)
n2=random.randint(1,100)
print(n1,n2)
n1+n2
# Out:
# 87 48
# 135

# %%
#wap ask user to enter three numbers n1 n2 n3  and calculate avg
n1=eval(input('enter number 1:'))
n2=eval(input('enter number 2:'))
n3=eval(input('enter number 3:'))
avg=(n1+n2+n3)/3
avg
# Out:
# enter number 1: 1
# enter number 2: 2
# enter number 3: 3
# 2.0

# %%
import random
import math
n1=random.randint(1,100)
n2=random.randint(1,100)
n3=random.randint(1,100)
print(n1, n2, n3)
avg=(n1+n2+n3)/3
avg1=math.ceil(avg)
print(f'the avg of {n1} , {n2} , {n3} is {avg1}')
# Out:
# 83 32 28
# the avg of 83 , 32 , 28 is 48

# %%
import random
name=input('enter your name :')
age=random.randint(1,10)
city=input('enter city :')
print(f'my name is {name} im {age} yrs old from {city}')
# Out:
# enter your name : python
# enter city : hyd
# my name is python im 7 yrs old from hyd

# %%
import random
import math 
import time
print('son : hi papa')
time.sleep(2)
print('fa : hi beta ')
time.sleep(2)
print('son : im going to school')
time.sleep(2)
print('fa : okay beta, i heared yr result came out')
time.sleep(2)
print('son : yes papa')
time.sleep(2)
print('fa : then what about the result')
time.sleep(2)
print('son : lets play a game i  tell you marks you tell me percentage')
time.sleep(2)
print('fa : exited...lets play!!')
time.sleep(2)
marathi=random.randint(35,100)
print(f'marathi : {marathi}')
math=random.randint(35,100)
print(f'math : {math}')
soc=random.randint(35,100)
print(f'soc : {soc}')
sci=random.randint(35,100)
print(f'sci : {sci}')
eng=random.randint(35,100)
print(f'eng : {eng}')
time.sleep(3)
percentage=(marathi+math+soc+sci+eng)*100/500
print(f'fa :percentage is {percentage}')
time.sleep(2)
print('son : yayyyyy!!!!!')
# Out:
# son : hi papa
# fa : hi beta
# son : im going to school
# fa : okay beta, i heared yr result came out
# son : yes papa
# fa : then what about the result
# son : lets play a game i  tell you marks you tell me percentage
# fa : exited...lets play!!
# marathi : 50
# math : 73
# soc : 97
# sci : 90
# eng : 75
# fa :percentage is 77.0
# son : yayyyyy!!!!!

# %%
#wap ask the user enter amount in dollers and convert in into rupees
import random
import math
doller=random.randint(1,1000)
rupees=doller*85
print(f'{doller} $ = {rupees} INR')
# Out:
# 45 $ = 3825 INR

# %%
import pandas as pd
dir(pd)
