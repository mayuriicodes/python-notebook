# %% [markdown]
# **basic representation**

# %% [markdown]
# - list elements is in square brackets

# %%
lst=[1,2,2,3,3]
min(lst)
# Out:
# 1

# %%
type(lst)
# Out:
# list

# %%
lst1=[1,1.2,'str']
lst1
# Out:
# [1, 1.2, 'str']

# %%
len(lst1)
# Out:
# 3

# %%
lst=[1,2,2,3,3]
sum(lst)
min(lst)
max(lst)
sorted(lst)
reversed(lst)  #all these are only work when the list contains the same type of data ex. string,int,float

# %%
for i in reversed(lst):
    print(i)
# Out:
# 3
# 3
# 2
# 2
# 1

# %%
lst1=[1,2,3,4]
lst2=['a','b','c']
lst1+lst2
#lst1*lst2#only work when both lists have integers
# Out:
# [1, 2, 3, 4, 'a', 'b', 'c']

# %% [markdown]
# **index**

# %%
lst3=[10,2,3,'a','b','c']
#-6 -5 -4 -3 -2 -1
#1  2  3  a  b  c
#0  1  2  3  4  5
lst3[0],lst3[-6]
# Out:
# (10, 10)

# %%
lst3=[10,2,[3]]
len(lst3)

    #print(f'positive index of {i} is {i}')
# Out:
# 3

# %%
lst3[2]
# Out:
# [3]

# %%
lst3[2][0]
# Out:
# 3

# %%
str1='python'
lst1=['p','y','t','h','o','n']

# %% [markdown]
# **in**

# %%
lst1=['p','y','t','h','o','n']
for i in lst1:
    print(i)
# Out:
# p
# y
# t
# h
# o
# n

# %%
str1='python'
for i in str1:
    print(i)
# Out:
# p
# y
# t
# h
# o
# n

# %% [markdown]
# **range vs in**

# %% [markdown]
# - when we have  use with index then go for range
# - when we have to use with only element go for in

# %% [markdown]
# **mutable vs immutable**

# %%
lst=[100,200,300,400]
lst[0]=20
lst
# Out:
# [20, 200, 300, 400]

# %% [raw]
# **lists are mutable**

# %%
dir('')
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
dir([])
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
lst=[100,200,300,400]
lst.clear()
lst
# Out:
# []

# %%
lst=[100,200,300,400]
lst.copy()
lst
# Out:
# [100, 200, 300, 400]

# %%
lst=[100,200,300,400]
lst.count(0)
lst
# Out:
# [100, 200, 300, 400]

# %% [markdown]
# **append**

# %% [markdown]
# - v-imp methond in lists
# - append means adding element at last
# - append method is used to store the output

# %%
l1=[10,20,30]
l1.append('aayein')
l1.append('baingan')
l1
# Out:
# [10, 20, 30, 'aayein', 'baingan']

# %%
l1=[10,20,30]
l1.append(['aayein','aayein'])#if you want to add multiple values at a time so you have to keep it into the list
l1
# Out:
# [10, 20, 30, ['aayein', 'aayein']]

# %%
#append a number from 1 to 5 in a list
l=[]
for i in range (6):
    l.append(i)
l
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
l=[]
for i in range (1,6):
    l.append(i)
l
# Out:
# [1, 2, 3, 4, 5]

# %%
#wap ask the user enter three random number perform the square of number, and print.
import random
for i in range(3):
    num=random.randint(1,100)
    print(num)
# Out:
# 81
# 98
# 82

# %%
# save those squares in a list
import random
lst=[]
for i in range(3):
    num=random.randint(1,100)
    lst.append(f'{num} : {num*num}')
lst
# Out:
# ['22 : 484', '89 : 7921', '15 : 225']

# %%
#odd-even 
l=[10,47,53,12,27]
even_list=[]
odd_list=[]
for i in l:
    if i%2==0:
        even_list.append(i)
    else:
        odd_list.append(i)
print(even_list)
print(odd_list)
# Out:
# [10, 12]
# [47, 53, 27]

# %%
que=['who is the PM of india :','what is the capital of india :','who are you :']
for i in que:
    ans=input(i)
# Out:
# who is the PM of india : modi
# what is the capital of india : delhi
# who are you : bhupendra jogi

# %% [markdown]
# **extend**

# %%
l1=[1,2,3,4,5]
l2=['a','b','c','d']
l2.extend(l1)
l2
# Out:
# ['a', 'b', 'c', 'd', 1, 2, 3, 4, 5]

# %%
l1=[1,2,3,4,5]
l2=['a','b','c','d']
print(l1+l2)
l1.extend(l2)
print(l1)#l1 will overwrite if we use extend
# Out:
# [1, 2, 3, 4, 5, 'a', 'b', 'c', 'd']
# [1, 2, 3, 4, 5, 'a', 'b', 'c', 'd']

# %% [markdown]
# **index**

# %% [markdown]
# - same as strings concept

# %%
l1=[10,20,30,40,'fk','u',40,50]
i1=l1.index(40)
print(l1.index(40,i1+1))
# Out:
# 6

# %% [markdown]
# **insert**
# - difference between append and insert

# %%
l1=[10,20,30,40,'aww','w',40,50]
id=l1.index('aww')
l1.insert(id+1,100)
l1
# Out:
# [10, 20, 30, 40, 'aww', 100, 'w', 40, 50]

# %% [markdown]
# **pop vs remove**

# %%
l1=[10,20,30,40,'aww','w',40,50]
l1.pop(5)
l1
# Out:
# [10, 20, 30, 40, 'aww', 40, 50]

# %%
l1=[10,20,30,40,'aww','w',40,50]
l1.remove('aww')
l1
# Out:
# [10, 20, 30, 40, 'w', 40, 50]

# %%
l1=[10,20,30,40,'aww','w',40,50]
del(l1[5])
l1
# Out:
# [10, 20, 30, 40, 'aww', 40, 50]

# %% [markdown]
# - if we want to delete element :
# - pop: based on index
# - remove : based on value
# - del is an inbuit function

# %% [markdown]
# **reverse-revesed**

# %% [markdown]
# - reverse is a method
# - reversed is a inbuit function

# %%
l1=[10,20,30,40,'aww','w',40,50]
l1.reverse()
l1
# Out:
# [50, 40, 'w', 'aww', 40, 30, 20, 10]

# %% [markdown]
# **in place**
# - when we perform the operations some times the value will overrite
# - if we see **inplace** word or **inplace=true**
# - this indicates the output will be overwrite in corresponding variable

# %%
l1=[10,20,30,40,'aww','w',40,50]
reversed(l1)
l1
# Out:
# [10, 20, 30, 40, 'aww', 'w', 40, 50]

# %% [markdown]
# **sort-sorted**

# %%
l1=[10,20,10,40,40,50]
sorted(l1)
#l1
# Out:
# [10, 10, 20, 40, 40, 50]

# %%
l1=[10,20,10,40,40,50]
l1.sort()
l1
# Out:
# [10, 10, 20, 40, 40, 50]

# %% [markdown]
# - inbuit functions applicable for for any datatype
# - but methods works wrt datatypes

# %%
dir(()) #tuple
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
tp=(1,2,3,1.5,1,'python-programming')
tp.count(1)
# Out:
# 2

# %%
tp=(1,2,3,1.5,1,'python-programming')
tp.index(3)
# Out:
# 2
