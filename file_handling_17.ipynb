# %%
#structured data---------------------------------packages
text files--------.txt                           normal
excel sheet-------.xlsx                          pandas
excel sheet-------.csv(comma seperated value)    pandas
json--------------.json                          json
word document-----.doc or docx                   doc
pdf---------------.pdf                           pypdf
#unstructured data---------------------------------------
xml---------------.xml                           xml
delta-------------.delta                         pandas
parquet-----------.parq                          pandas
audio-------------.mp3                           pytext/pydub
video-------------.mp4 or .XVID                  pytext/mutagen
image-------------.png or .jpg or .jpeg          opencv/pillow/matplotlib

# %% [markdown]
# **to read the data files**
# - location
# - filename
# - extension

# %%
'C:\\Users\Admin\Downloads\online-matrimonial-project-in-php-master\online-matrimonial-project-in-php-master\db'
# Out:
# 'C:\\Users\\Admin\\Downloads\\online-matrimonial-project-in-php-master\\online-matrimonial-project-in-php-master\\db'

# %%
#to open the file
file_location=r'C:\Users\Admin\Documents\jy\sampleData\simple.txt'
open(file_location)
# Out:
# <_io.TextIOWrapper name='C:\\Users\\Admin\\Documents\\jy\\sampleData\\simple.txt' mode='r' encoding='cp1252'>

# %%
#to read the file
file_location=r'C:\Users\Admin\Documents\jy\sampleData\simple.txt'
open(file_location).read()
# Out:
# 'Lorem ipsum dolor sit amet, consectetur adipiscing elit. \nSed do eiusmod tempor incididunt ut labore et dolore magna aliqua.\n\nThis sample TXT file is provided by Sample-Files.com. Visit us for more sample files and resources.'

# %%
#to fetch the data of a file
file_location=r'C:\Users\Admin\Documents\jy\sampleData\simple.txt'
file=open(file_location)
data=file.read()
print(data)
# Out:
# Lorem ipsum dolor sit amet, consectetur adipiscing elit.
# Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
#
# This sample TXT file is provided by Sample-Files.com. Visit us for more sample files and resources.

# %% [markdown]
# **note**
# - above process is only for text files
# - for other files we need packages

# %% [markdown]
# **method-2 using with**

# %%
file_location=r'C:\Users\Admin\Documents\jy\sampleData\simple.txt'
with open(file_location)as file:
    data=file.read()
print(data)
# Out:
# Lorem ipsum dolor sit amet, consectetur adipiscing elit.
# Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
#
# This sample TXT file is provided by Sample-Files.com. Visit us for more sample files and resources.

# %% [markdown]
# **method-3**

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Admin\\Documents\\jy'

# %% [raw]
# - when we open file three arguments are important
# - file: which needs file location
# - model:
#     - 'r'       open for reading (default)
#     - 'w'       open for writing, truncating the file first
#     - 'x'       create a new file and open it for writing
#     - 'a'       open for writing, appending to the end of the file if it exists
#     - 'b'       binary mode
#     - 't'       text mode (default)
#     - '+'       open a disk file for updating (reading and writing)

# %% [markdown]
# **writing a file**

# %%
file_name='dummy.txt'
file=open(file_name,mode='w')
file.write('hello how are you')
# Out:
# 17

# %%
file_name='dummy1.txt'
with open(file_name,mode='w'):
    file.write('hello how are you')

# %%
file_name='xyzz.txt'
with open(file_name,mode='x'):
    file.write('hello how are you')

# %%
file_name='xyzzz.txt'
file=open(file_name,mode='w')    
file.write('hello how are you')
# Out:
# 17

# %%
file_name='xyzz.txt'
try:
    file=open(file_name,mode='x')
except Exception as e:
    print(e)
    file.write('hello how are you')
# Out:
# [Errno 17] File exists: 'xyzz.txt'

# %%
file_location=r'C:\Users\Admin\Documents\jy\sampleData\simple.txt'
file=open(file_location,mode='r',encoding='utf-8-sig')
count=0
for line in file:
    count=count+1
count
# Out:
# 4

# %%
file_location=r'C:\Users\Admin\Documents\jy\sampleData\simple.txt'
open(file_location)
# Out:
# <_io.TextIOWrapper name='C:\\Users\\Admin\\Documents\\jy\\sampleData\\simple.txt' mode='r' encoding='cp1252'>

# %%
file_location=r'C:\Users\Admin\Documents\jy\sampleData\simple.txt'
file=open(file_location,mode='r',encoding='utf-8-sig')
for i in file:
    print (i)
# Out:
# Lorem ipsum dolor sit amet, consectetur adipiscing elit.
#
# Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
#
#
#
# This sample TXT file is provided by Sample-Files.com. Visit us for more sample files and resources.

# %% [markdown]
# **enumerate**
#
# - similar to zip
#
# - enumerate will provide index and line

# %%
file_location=r'C:\Users\Admin\Documents\jy\sampleData\simple.txt'
file=open(file_location,mode='r',encoding='utf-8-sig')
for index,line in enumerate(file):
    print(index,line)
# Out:
# 0 Lorem ipsum dolor sit amet, consectetur adipiscing elit.
#
# 1 Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
#
# 2
#
# 3 This sample TXT file is provided by Sample-Files.com. Visit us for more sample files and resources.

# %%
for i in range(4):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
index+1
# Out:
# 4

# %%
i
# Out:
# 3

# %%
index
# Out:
# 3

# %%
file_location=r'C:\Users\Admin\Documents\jy\sampleData\leads-100.csv'
open(file_location)
# Out:
# <_io.TextIOWrapper name='C:\\Users\\Admin\\Documents\\jy\\sampleData\\leads-100.csv' mode='r' encoding='cp1252'>

# %%
file_location=r'C:\Users\Admin\Documents\jy\sampleData\leads-100.csv'
file=open(file_location)
for i in file:
    print(i)
# Out:
# Index,Account Id,Lead Owner,First Name,Last Name,Company,Phone 1,Phone 2,Email 1,Email 2,Website,Source,Deal Stage,Notes
#
# 1,0970F99ED4a2CE4,Bethany Dixon,Victor,Cochran,"Grimes, Madden and Huff",+1-532-344-1362,2754733370,hatkinson@mclaughlin.com,ygibbs@guzman.com,http://www.rosales-molina.com/,Retargeting Ads,New Lead,Speak own such.
#
# 2,e9AABddbCA4AFee,Andres Callahan,Maureen,Fuentes,Crosby Inc,001-672-799-2170x5610,+1-887-577-1205x5686,bshelton@wilkins.org,hunter84@jefferson.com,https://www.myers-mendez.biz/,Google Ads,Closed Won,Consumer environment still.
#
# 3,99CF54fE56dDc5e,Angel Ortega,Ralph,Murillo,Velasquez-Hardin,985.939.5411x2641,+1-852-904-1856x071,mmooney@savage-shaw.com,kelsey70@leach.net,https://www.chase-miller.com/,Chatbot,Contacted,Onto goal father easy development.
#
# ...

# %%
#to align the specing
file_location=r'C:\Users\Admin\Documents\jy\sampleData\leads-100.csv'
file=open(file_location)
for i in file:
    print(i.strip())
# Out:
# Index,Account Id,Lead Owner,First Name,Last Name,Company,Phone 1,Phone 2,Email 1,Email 2,Website,Source,Deal Stage,Notes
# 1,0970F99ED4a2CE4,Bethany Dixon,Victor,Cochran,"Grimes, Madden and Huff",+1-532-344-1362,2754733370,hatkinson@mclaughlin.com,ygibbs@guzman.com,http://www.rosales-molina.com/,Retargeting Ads,New Lead,Speak own such.
# 2,e9AABddbCA4AFee,Andres Callahan,Maureen,Fuentes,Crosby Inc,001-672-799-2170x5610,+1-887-577-1205x5686,bshelton@wilkins.org,hunter84@jefferson.com,https://www.myers-mendez.biz/,Google Ads,Closed Won,Consumer environment still.
# 3,99CF54fE56dDc5e,Angel Ortega,Ralph,Murillo,Velasquez-Hardin,985.939.5411x2641,+1-852-904-1856x071,mmooney@savage-shaw.com,kelsey70@leach.net,https://www.chase-miller.com/,Chatbot,Contacted,Onto goal father easy development.
# ...

# %%
file_location=r'C:\Users\Admin\Documents\jy\sampleData\leads-100.csv'
file=open(file_location)
for i in file:
    if i.startswith('4'):
        print(i)
# Out:
# 4,5B8C661A897ACE3,Dana Mcdonald,Richard,Obrien,Barrett Ltd,223.427.4047,(240)452-2332x4601,trankaren@parks.biz,normanvickie@giles-ewing.com,http://watts.com/,Trade Show,Proposal Sent,Medical education throughout lay.
#
# 40,75db9b69462EABa,Gabriella Berg,Wanda,Rodgers,Blair Ltd,281.729.5708,4677131230,mckenzie58@bentley-graves.com,tshepard@ball-finley.biz,http://ho.com/,Google Ads,Closed Lost,Ready at water next media our magazine none.
#
# 41,dffe85C1BBed1b7,Tom Murray,Roy,Cox,Hoffman-Moses,(827)956-9122x41683,(750)674-9148,mpacheco@ware.com,deanrodriguez@pham-schwartz.com,http://carpenter.com/,Purchased List,Negotiation,Threat local father less.
#
# 42,BbfcD0A43C0CEfe,Martin Nixon,Isaac,Duarte,"Zamora, Sharp and Bradley",001-728-600-4302,001-427-978-6104x294,awoodard@gentry.net,plowery@schmidt.org,http://www.solomon.info/,Networking Event,Re-engagement,Real exactly these official trial member.
#
# ...

# %%
file_location=r'C:\Users\Admin\Documents\jy\sampleData\leads-100.csv'
file=open(file_location)
for line in file:
    print(line.strip('//'))
# Out:
# Index,Account Id,Lead Owner,First Name,Last Name,Company,Phone 1,Phone 2,Email 1,Email 2,Website,Source,Deal Stage,Notes
#
# 1,0970F99ED4a2CE4,Bethany Dixon,Victor,Cochran,"Grimes, Madden and Huff",+1-532-344-1362,2754733370,hatkinson@mclaughlin.com,ygibbs@guzman.com,http://www.rosales-molina.com/,Retargeting Ads,New Lead,Speak own such.
#
# 2,e9AABddbCA4AFee,Andres Callahan,Maureen,Fuentes,Crosby Inc,001-672-799-2170x5610,+1-887-577-1205x5686,bshelton@wilkins.org,hunter84@jefferson.com,https://www.myers-mendez.biz/,Google Ads,Closed Won,Consumer environment still.
#
# 3,99CF54fE56dDc5e,Angel Ortega,Ralph,Murillo,Velasquez-Hardin,985.939.5411x2641,+1-852-904-1856x071,mmooney@savage-shaw.com,kelsey70@leach.net,https://www.chase-miller.com/,Chatbot,Contacted,Onto goal father easy development.
#
# ...
